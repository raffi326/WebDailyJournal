# %% [markdown]
# **Latihan Pyhton Literals - strings**

# %%
print('"I\'m"', '""learning""', '"""Python"""')
# Out:
# "I'm" ""learning"" """Python"""

# %% [markdown]
# **Latihan Variabel**

# %%
Darjo = 2
Darno = 5
Waginem = 6

print(f"Darjo: {Darjo}, Darno: {Darno}, Waginem: {Waginem}")

#total apel tambah
totalApel = Darjo + Darno + Waginem
print(f"Total Apel: {totalApel}")

#aritmatik perkalian
hasilPerkalian = totalApel * Darjo * Waginem
print(f"Total Apel Perkalian : {hasilPerkalian}")
# Out:
# Darjo: 2, Darno: 5, Waginem: 6
# Total Apel: 13
# Total Apel Perkalian : 156

# %% [markdown]
# **Latihan: Variables: a simple converter**

# %%
kilometer = 12.25
mil = 7.38


miles_to_kilometers = 1 * 1.61
kilometers_to_miles = 1 / 1.61

#koversinya
mil_ke_km = 7.38 * 1.61
km_ke_mil = 12.25 / 1.61


print("1 mil adalah", round(miles_to_kilometers, 2), "kilometer")
print("1 kilometer adalah", round(kilometers_to_miles, 2), "mil")

#hasil untuk konversinya
print(mil, "mil adalah", round(mil_ke_km, 2), "kilometer")
print(kilometer, "kilometer adalah", round(km_ke_mil, 2), "mil")
# Out:
# 1 mil adalah 1.61 kilometer
# 1 kilometer adalah 0.62 mil
# 7.38 mil adalah 11.88 kilometer
# 12.25 kilometer adalah 7.61 mil

# %% [markdown]
# **Latihan: Operators and expressions**

# %%
x = -1
x = float(x)

# (3x^3) - (2x^2) + 3x - 1
y = (3 * x**3) - (2 * x**2) + (3 * x) - 1

print("y =", y)
# Out:
# y = -9.0

# %% [markdown]
# Apa outputnya?
#
# var = 2
# var = 3
# print(var)
#
# Variabel var pertama kali diisi 2, lalu diubah menjadi 3.
#
# Karena var = 3 menimpa nilai sebelumnya, maka output print(var) adalah 3

# %% [markdown]
# **my_var** (legal)
#
# **m**(legal)
#
# **101**  (ilegal, tidak boleh diawali angka)
#
# **averylongvariablename** (legal)
#
# **m101** (legal)
#
# **m 101**  (ilegal, tidak boleh ada spasi)
#
# **Del**(legal, tapi tidak disarankan karena mirip dengan kata kunci `del`)
#
# **del** (ilegal, karena `del` adalah keyword di Python)

# %%
a = '1'
b = "1"
print(a + b)
# Out:
# 11

# %%
a = 6
b = 3
a /= 2 * b
print(a)
# Out:
# 1.0

# %% [markdown]
# **Latihan: mana yang seharusnya menjadi komentar, mana yang tidak**
#
# **#test #komentar **
#
# **print("Hai...")** #ini kode bukan komentar karena jelas di depan juga print
#
# **#test1**  #komentar
#
# **#test2**  #komentar

# %% [markdown]
# **Latihan : Simple input and output**

# %%
a = float(input("Masukkan nilai a: "))
b = float(input("Masukkan nilai b: "))


penjumlahan = a + b
pengurangan = a - b
perkalian = a * b
pembagian = a / b


# Cetak hasil operasi
print("\nHasil Perhitungan:")
print(f"Penjumlahan: {penjumlahan}")
print(f"Pengurangan: {pengurangan}")
print(f"Perkalian: {perkalian}")
print(f"Pembagian: {pembagian}")
# Out:
# Masukkan nilai a: 10
# Masukkan nilai b: 11
#
# Hasil Perhitungan:
# Penjumlahan: 21.0
# Pengurangan: -1.0
# Perkalian: 110.0
# Pembagian: 0.9090909090909091

# %% [markdown]
# **Latihan: Operators and expressions**

# %%
x = float(input("Masukkan nilai x: "))

y = (1 / (x + 1/(x + 1/(x + 1/x))))


print(f"x = {x}")
print(f"y = {y}")
# Out:
# Masukkan nilai x: 10
# x = 10.0
# y = 0.09901951266867294
