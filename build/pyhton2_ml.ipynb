# %% [markdown]
# **Latihan: Questions and answers**

# %%
a = int(input("Sampel Input: "))

print("Expected output:", a>=100)
# Out:
# Sampel Input: 100
# Expected output: True

# %% [markdown]
# **Latihan 1**
#
# Memasukan bilangan bulat dan mendeteksi bilangan tersebut genap / ganjil.

# %%
bil = int(input("Masukan bilangan bulat: "))

if(bil%2 == 0):
    print("genap")
else:
    print("ganjil")
# Out:
# Masukan bilangan bulat: 10
# genap

# %% [markdown]
# **Latihan 2**
#
# ![Cuplikan layar 2025-03-08 225926.png](data:image/png;base64,...)

# %%
print("Masukan nilai koordinat")
x = int(input("Nilai x: "))
y = int(input("Nilai y: "))

if x>0 and y>0:
    print("Koordinat ("+ str(x) + ","+ str(y) +") berada pada Kuadran I" )
elif x<0 and y>0:
    print("Koordinat ("+ str(x) + ","+ str(y) +") berada pada Kuadran II" )
elif x<0 and y<0:
    print("Koordinat ("+ str(x) + ","+ str(y) +") berada pada Kuadran III" )
elif x>0 and y<0:
    print("Koordinat ("+ str(x) + ","+ str(y) +") berada pada Kuadran IV" )
else:
    pass
# Out:
# Masukan nilai koordinat
# Nilai x: 10
# Nilai y: 11
# Koordinat (10,11) berada pada Kuadran I

# %% [markdown]
# **Latihan 3**
# Mencari bilangan terbesar, dari 3 inputan (a, b dan c)

# %%
num1 = int(input("First Number : "))
num2 = int(input("Second Number : "))
num3 = int(input("Third Number : "))

#set number1 sebagai yang terbesar
largestNum = num1

#deteksi apakah num2 > num1
if num2 > largestNum:
    largestNum = num2

#deteksi apakah num3 > num2
if num3 > largestNum:
    largestNum = num3

print("The largest number is: ", largestNum)
# Out:
# First Number : 10
# Second Number : 12
# Third Number : 14
# The largest number is:  14

# %% [markdown]
# **Latihan**

# %%
plant = input("Please input a best plant = ")

if plant == "Spathiphyllum":
    print("Yes - Spathiphyllum is the best plant ever!")
elif plant == "spathiphyllum":
    print("No, I want a big Spathiphyllum!")
else:
    print("Spathiphyllum! Not "+ plant +"!")
# Out:
# Please input a best plant = 10
# Spathiphyllum! Not 10!

# %% [markdown]
# **Latihan**
# Test your code using the data we've provided.
#
# Sample input: 10000
#
# Expected output: The tax is: 1244.0 thalers
#
# Sample input: 100000
#
# Expected output: The tax is: 19470.0 thalers
#
# Sample input: 1000
#
# Expected output: The tax is: 0.0 thalers
#
# Sample input: -100
#
# Expected output: The tax is: 0.0 thalers

# %%
income = float(input("Enter the annual income: "))
tax = 0

if income<85528:
    tax = 0.18 * income - 556.2
else:
    tax = 14839 + 0.2 + 0.32 * (income - 85528)

tax = round(tax, 0)

if tax<0:
    tax = 0

print("The tax is:", tax, "thalers")
# Out:
# Enter the annual income: 10000
# The tax is: 1244.0 thalers

# %% [markdown]
# **LATIHAN MENGECEK TAHUN KABISAT DENGAN FUNGSI**

# %%
def is_leap_year(year):
    if year < 1582:
        return "Not within the Gregorian calendar period"
    return (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

year = int(input("Enter a year: "))
if is_leap_year(year):
    print("Leap year")
else:
    print("Common year")
# Out:
# Enter a year: 2022
# Common year

# %% [markdown]
# **LATIHAN LATIHAN**

# %%
x, y, z = 10, 20, 30

print(x != y)  # True
print(y < z)   # True
print((x + z) > y)  # True
# Out:
# True
# True
# True

# %%
nilai = 80

if nilai >= 80:
    print("Nilai A")
elif nilai >= 70:
    print("Nilai B")
elif nilai >= 60:
    print("Nilai C")
else:
    print("Nilai D")
# Out:
# Nilai A

# %%
a = "Python"
b = "python"

if a.lower() == b.lower():
    print("Kedua string sama setelah konversi ke huruf kecil")
else:
    print("String berbeda")
# Out:
# Kedua string sama setelah konversi ke huruf kecil

# %%
x = 15
y = 25

if x < 20 and y > 20:
    print("Kedua kondisi benar")
else:
    print("Salah satu kondisi salah")
# Out:
# Kedua kondisi benar

# %% [markdown]
# **lATIHAN**

# %%
secretNum = 777

guessNum = 0

while guessNum != secretNum:
    guessNum = int(input("Input angka rahasia untuk berhenti : "))
    if guessNum != secretNum:
        print("Perulangan akan terus lanjut...")

print("Well done, Congrats...")
# Out:
# Input angka rahasia untuk berhenti : 777
# Well done, Congrats...

# %% [markdown]
# **Latihan**

# %%
import time

for i in range(1, 6):  # Memulai dari 1 sampai 5
    print(i, "Mississippi")  # Memperbaiki ejaan "Mississippi"
    time.sleep(1)  # Jeda 1 detik

print("Ready or not, here I come!")  # Pesan akhir
# Out:
# 1 Mississippi
# 2 Mississippi
# 3 Mississippi
# 4 Mississippi
# 5 Mississippi
# Ready or not, here I come!

# %% [markdown]
# ### Latihan
#
# 1. Buatlah perulangan dengan menggunakan for yang mulai dari 0 sampai dengan 10, dan cetak nomer ganjil pada layar.
#
# 2. Buatlah perulangan dengan menggunakan while dari 0 sampai dengan 10, dan cetak nomer ganjil pada layar
#
# 3. Buatlah sebuah program dengan perulangan for dan statement break. Program harus diiterasi sebanyak jumlah karakter didalam sebuah alamat email, dan loop akan berhenti jika menemukan simbol '@' dan cetak karakter yang ditemukan sebelum simbol '@' didalam sebuah line
#
# 4. Buatlah sebuah perulangan loop dan statement continue. Program harus diiterasi sebanyak nomer yang ditemukan dalam string (digit = "0165031806510"), ganti 0 dengan x, lalu cetak string yang telah dimodifikasi.

# %%
# Menampilkan angka ganjil dari 1 sampai 10 menggunakan for
for i in range(1, 11):
    if i % 2 != 0:
        print(i, end=' ')
print("\n")

# Menampilkan angka ganjil dari 1 sampai 10 menggunakan while
x = 1
while x < 11:
    if x % 2 != 0:
        print(x, end=' ')
    x += 1
print("\n")

# Menampilkan karakter sebelum simbol '@' dalam email
email = "ratna.lestari@ugm.ac.id"
for ch in email:
    if ch == "@":
        break
    print(ch, end='')
print("\n")

# Mengganti '0' dengan 'x' dalam string angka
digit = "0165031806510"
modified_digit = ""
for num in digit:
    if num == "0":
        modified_digit += "x"
        continue
    modified_digit += num

print("String setelah penggantian:", modified_digit)
# Out:
# 1 3 5 7 9
#
# 1 3 5 7 9
#
# ratna.lestari
#
# String setelah penggantian: x165x318x651x

# %% [markdown]
# **LATIHAN OUTPUT KODE BERIKUT**

# %%
n = 3

while n > 0:
    print(n + 1)
    n -= 1
else:
    print(n)
# Out:
# 4
# 3
# 2
# 0

# %%
n = range(4)

for num in n:
    print(num - 1)
else:
    print(num)
# Out:
# -1
# 0
# 1
# 2
# 3

# %%
for i in range(0, 6, 3):
    print(i)
# Out:
# 0
# 3
